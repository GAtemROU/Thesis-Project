# %% [markdown]
# # Imports

# %%
from utils.visulisation import plot_confusion_matrices, plot_history
from utils.log_extraction import extract_confusion_matrices, extract_loss_history, extract_val_history

# %%
with open("../experiments/heatmaps_base_128_final/log.txt", "r") as f:
    log_file = f.read()
loss_history = extract_loss_history(log_file)
plot_history(loss_history, metric='Loss')

# %%
with open("../experiments/heatmaps_base_128_final/log.txt", "r") as f:
    log_file = f.read()
val_history = extract_val_history(log_file)
plot_history(val_history, 'Validation Accuracy')
